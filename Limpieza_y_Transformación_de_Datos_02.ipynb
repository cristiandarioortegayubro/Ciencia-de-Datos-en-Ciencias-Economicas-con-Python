# %% [markdown]
# <a href="https://colab.research.google.com/github/cristiandarioortegayubro/Ciencia-de-Datos-en-Ciencias-Economicas-con-Python/blob/master/Limpieza_y_Transformaci%C3%B3n_de_Datos_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Pandas** - Limpieza y Transformación de Datos - **02**

# %% [markdown]
# ## **Modificando el código** - Mi primer DataFrame - **01**

# %%
import numpy as np
import pandas as pd
import pandas_datareader as data
BTC2019 = data.DataReader("BTC-USD", start="2018-12-31", end="2019-12-31", data_source="yahoo")
df = pd.DataFrame(BTC2019)
df.head()
# Out:
#                    High          Low  ...      Volume    Adj Close
# Date                                  ...
# 2018-12-31  3868.742920  3725.867432  ...  4661840806  3742.700439
# 2019-01-01  3850.913818  3707.231201  ...  4324200990  3843.520020
# 2019-01-02  3947.981201  3817.409424  ...  5244856835  3943.409424
# 2019-01-03  3935.685059  3826.222900  ...  4530215218  3836.741211
# 2019-01-04  3865.934570  3783.853760  ...  4847965467  3857.717529
#
# [5 rows x 6 columns]

# %% [markdown]
# ## Limpieza y Transformación de los Datos

# %% [markdown]
# ### Transformación

# %%
df.insert(0,column="Date",value=df.index.values)
df.head()
# Out:
#                  Date         High  ...      Volume    Adj Close
# Date                                ...
# 2018-12-31 2018-12-31  3868.742920  ...  4661840806  3742.700439
# 2019-01-01 2019-01-01  3850.913818  ...  4324200990  3843.520020
# 2019-01-02 2019-01-02  3947.981201  ...  5244856835  3943.409424
# 2019-01-03 2019-01-03  3935.685059  ...  4530215218  3836.741211
# 2019-01-04 2019-01-04  3865.934570  ...  4847965467  3857.717529
#
# [5 rows x 7 columns]

# %%
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#         Date         High          Low  ...        Close      Volume    Adj Close
# 0 2018-12-31  3868.742920  3725.867432  ...  3742.700439  4661840806  3742.700439
# 1 2019-01-01  3850.913818  3707.231201  ...  3843.520020  4324200990  3843.520020
# 2 2019-01-02  3947.981201  3817.409424  ...  3943.409424  5244856835  3943.409424
# 3 2019-01-03  3935.685059  3826.222900  ...  3836.741211  4530215218  3836.741211
# 4 2019-01-04  3865.934570  3783.853760  ...  3857.717529  4847965467  3857.717529
#
# [5 rows x 7 columns]

# %%
df.insert(1,column="Day",value=pd.DatetimeIndex(df['Date']).day_name())
df.head()
# Out:
#         Date        Day         High  ...        Close      Volume    Adj Close
# 0 2018-12-31     Monday  3868.742920  ...  3742.700439  4661840806  3742.700439
# 1 2019-01-01    Tuesday  3850.913818  ...  3843.520020  4324200990  3843.520020
# 2 2019-01-02  Wednesday  3947.981201  ...  3943.409424  5244856835  3943.409424
# 3 2019-01-03   Thursday  3935.685059  ...  3836.741211  4530215218  3836.741211
# 4 2019-01-04     Friday  3865.934570  ...  3857.717529  4847965467  3857.717529
#
# [5 rows x 8 columns]

# %%
df.insert(2,column="Month",value=pd.DatetimeIndex(df['Date']).month_name())
df.head()
# Out:
#         Date        Day     Month  ...        Close      Volume    Adj Close
# 0 2018-12-31     Monday  December  ...  3742.700439  4661840806  3742.700439
# 1 2019-01-01    Tuesday   January  ...  3843.520020  4324200990  3843.520020
# 2 2019-01-02  Wednesday   January  ...  3943.409424  5244856835  3943.409424
# 3 2019-01-03   Thursday   January  ...  3836.741211  4530215218  3836.741211
# 4 2019-01-04     Friday   January  ...  3857.717529  4847965467  3857.717529
#
# [5 rows x 9 columns]

# %%
df.rename(columns={'Adj Close':'Adj_Close'}, inplace=True)
df.head()
# Out:
#         Date        Day     Month  ...        Close      Volume    Adj_Close
# 0 2018-12-31     Monday  December  ...  3742.700439  4661840806  3742.700439
# 1 2019-01-01    Tuesday   January  ...  3843.520020  4324200990  3843.520020
# 2 2019-01-02  Wednesday   January  ...  3943.409424  5244856835  3943.409424
# 3 2019-01-03   Thursday   January  ...  3836.741211  4530215218  3836.741211
# 4 2019-01-04     Friday   January  ...  3857.717529  4847965467  3857.717529
#
# [5 rows x 9 columns]

# %%
df['Pct_Change'] = df.Adj_Close.pct_change()*100
df.head()
# Out:
#         Date        Day     Month  ...      Volume    Adj_Close  Pct_Change
# 0 2018-12-31     Monday  December  ...  4661840806  3742.700439         NaN
# 1 2019-01-01    Tuesday   January  ...  4324200990  3843.520020    2.693766
# 2 2019-01-02  Wednesday   January  ...  5244856835  3943.409424    2.598904
# 3 2019-01-03   Thursday   January  ...  4530215218  3836.741211   -2.704974
# 4 2019-01-04     Friday   January  ...  4847965467  3857.717529    0.546722
#
# [5 rows x 10 columns]

# %%
df['Diff'] = df.Adj_Close.diff()
df.head()
# Out:
#         Date        Day     Month  ...    Adj_Close  Pct_Change        Diff
# 0 2018-12-31     Monday  December  ...  3742.700439         NaN         NaN
# 1 2019-01-01    Tuesday   January  ...  3843.520020    2.693766  100.819580
# 2 2019-01-02  Wednesday   January  ...  3943.409424    2.598904   99.889404
# 3 2019-01-03   Thursday   January  ...  3836.741211   -2.704974 -106.668213
# 4 2019-01-04     Friday   January  ...  3857.717529    0.546722   20.976318
#
# [5 rows x 11 columns]

# %%
df['Eval'] = df.eval('Close >= Open')
df.head()
# Out:
#         Date        Day     Month  ...  Pct_Change        Diff   Eval
# 0 2018-12-31     Monday  December  ...         NaN         NaN  False
# 1 2019-01-01    Tuesday   January  ...    2.693766  100.819580   True
# 2 2019-01-02  Wednesday   January  ...    2.598904   99.889404   True
# 3 2019-01-03   Thursday   January  ...   -2.704974 -106.668213  False
# 4 2019-01-04     Friday   January  ...    0.546722   20.976318   True
#
# [5 rows x 12 columns]

# %% [markdown]
# ### Limpieza

# %%
df.dropna(how='any', inplace=True)
df.head()
# Out:
#         Date        Day    Month  ...  Pct_Change        Diff   Eval
# 1 2019-01-01    Tuesday  January  ...    2.693766  100.819580   True
# 2 2019-01-02  Wednesday  January  ...    2.598904   99.889404   True
# 3 2019-01-03   Thursday  January  ...   -2.704974 -106.668213  False
# 4 2019-01-04     Friday  January  ...    0.546722   20.976318   True
# 5 2019-01-05   Saturday  January  ...   -0.324621  -12.522949  False
#
# [5 rows x 12 columns]

# %% [markdown]
# ## Formatos del DataFrame

# %% [markdown]
# ### Numeros de decimales

# %%
pd.options.display.precision = 2
df.head()
# Out:
#         Date        Day    Month     High  ...  Adj_Close  Pct_Change    Diff   Eval
# 1 2019-01-01    Tuesday  January  3850.91  ...    3843.52        2.69  100.82   True
# 2 2019-01-02  Wednesday  January  3947.98  ...    3943.41        2.60   99.89   True
# 3 2019-01-03   Thursday  January  3935.69  ...    3836.74       -2.70 -106.67  False
# 4 2019-01-04     Friday  January  3865.93  ...    3857.72        0.55   20.98   True
# 5 2019-01-05   Saturday  January  3904.90  ...    3845.19       -0.32  -12.52  False
#
# [5 rows x 12 columns]
